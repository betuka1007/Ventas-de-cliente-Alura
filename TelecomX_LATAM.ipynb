# %% [markdown]
# <a href="https://colab.research.google.com/github/betuka1007/Ventas-de-cliente-Alura/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
import numpy as np

# %%
import json

# %%
telecomm_data = '/content/TelecomX_Data.json'

# %%
pd_telecomm = pd.read_json(telecomm_data)

# %%
pd_telecomm.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformación

# %%
pd_telecomm_customer = pd.json_normalize(pd_telecomm['customer'])

# %%
pd_telecomm_phone = pd.json_normalize(pd_telecomm['phone'])

# %%
pd_telecomm_internet = pd.json_normalize(pd_telecomm['internet'])

# %%
pd_telecomm_account = pd.json_normalize(pd_telecomm['account'])

# %%
pd_customerID = pd_telecomm['customerID']

# %%
pd_telecomm_Churn = pd_telecomm['Churn']

# %%
pd_telecomm = pd.concat([pd_customerID, pd_telecomm_customer, pd_telecomm_phone, pd_telecomm_internet, pd_telecomm_account, pd_telecomm_Churn], axis=1)

# %%
pd_telecomm.to_csv('pd_telecomm.csv')

# %%
pd_telecomm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   gender            7267 non-null   object
#  2   SeniorCitizen     7267 non-null   int64
#  3   Partner           7267 non-null   object
#  4   Dependents        7267 non-null   object
#  5   tenure            7267 non-null   int64
#  6   PhoneService      7267 non-null   object
#  7   MultipleLines     7267 non-null   object
#  8   InternetService   7267 non-null   object
#  9   OnlineSecurity    7267 non-null   object
#  10  OnlineBackup      7267 non-null   object
#  11  DeviceProtection  7267 non-null   object
#  12  TechSupport       7267 non-null   object
#  13  StreamingTV       7267 non-null   object
#  14  StreamingMovies   7267 non-null   object
#  15  Contract          7267 non-null   object
# ...

# %%
pd_telecomm.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7262       False   False          False    False       False   False
# 7263       False   False          False    False       False   False
# 7264       False   False          False    False       False   False
# 7265       False   False          False    False       False   False
# 7266       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
pd_telecomm.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# Churn               0
# dtype: int64

# %%
pd_telecomm.replace(['', ' ', 'NA', 'null'], np.nan, inplace=True)

# %%
pd_telecomm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   gender            7267 non-null   object
#  2   SeniorCitizen     7267 non-null   int64
#  3   Partner           7267 non-null   object
#  4   Dependents        7267 non-null   object
#  5   tenure            7267 non-null   int64
#  6   PhoneService      7267 non-null   object
#  7   MultipleLines     7267 non-null   object
#  8   InternetService   7267 non-null   object
#  9   OnlineSecurity    7267 non-null   object
#  10  OnlineBackup      7267 non-null   object
#  11  DeviceProtection  7267 non-null   object
#  12  TechSupport       7267 non-null   object
#  13  StreamingTV       7267 non-null   object
#  14  StreamingMovies   7267 non-null   object
#  15  Contract          7267 non-null   object
# ...

# %%
pd_telecomm[pd_telecomm['Charges.Total'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ  Female              0     Yes        Yes       0
# 1775  2520-SGTTA  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    Male              0      No        Yes       0
# 2075  2923-ARZLG    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    Male              0      No        Yes       0
# 2308  3213-VVOLG    Male              0     Yes        Yes       0
# 2930  4075-WKNIU  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    Male              0     Yes        Yes       0
# 3203  4472-LVYGI  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 975            No  No phone service             DSL                  Yes  ...
# ...

# %%
pd_telecomm[pd_telecomm['Churn'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW  Female              0      No         No      11
# 75    0120-YZLQA    Male              0      No         No      71
# 96    0154-QYHJU    Male              0      No         No      29
# 98    0162-RZGMZ  Female              1      No         No       5
# 175   0274-VVQOQ    Male              1     Yes         No      65
# ...          ...     ...            ...     ...        ...     ...
# 7158  9840-GSRFX  Female              0      No         No      14
# 7180  9872-RZQQB  Female              0     Yes         No      49
# 7211  9920-GNDMB    Male              0      No         No       9
# 7239  9955-RVWSC  Female              0     Yes        Yes      67
# 7247  9966-VYRTZ  Female              0     Yes        Yes      31
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic                  Yes  ...
# ...

# %%
pd_telecomm['customerID'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7262    False
# 7263    False
# 7264    False
# 7265    False
# 7266    False
# Name: customerID, Length: 7267, dtype: bool

# %%
pd_telecomm['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %%
pd_telecomm.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# Churn                object
# dtype: object

# %%
pd_telecomm['Partner'] = pd_telecomm['Partner'].astype('category')

# %%
pd_telecomm['Dependents'] = pd_telecomm['Dependents'].astype('category')

# %%
pd_telecomm['PhoneService'] = pd_telecomm['PhoneService'].astype('category')

# %%
pd_telecomm['MultipleLines'] = pd_telecomm['MultipleLines'].astype('category')

# %%
pd_telecomm['OnlineSecurity'] = pd_telecomm['OnlineSecurity'].astype('category')

# %%
pd_telecomm['OnlineBackup'] = pd_telecomm['OnlineBackup'].astype('category')

# %%
pd_telecomm['DeviceProtection'] = pd_telecomm['DeviceProtection'].astype('category')

# %%
pd_telecomm['TechSupport'] = pd_telecomm['TechSupport'].astype('category')

# %%
pd_telecomm['StreamingTV'] = pd_telecomm['StreamingTV'].astype('category')

# %%
pd_telecomm['StreamingMovies'] = pd_telecomm['StreamingMovies'].astype('category')

# %%
pd_telecomm['PaperlessBilling'] = pd_telecomm['PaperlessBilling'].astype('category')

# %%
pd_telecomm['Charges.Total'] = pd_telecomm['Charges.Total'].astype('float')

# %%
pd_telecomm['Churn'] = pd_telecomm['Churn'].astype('category')

# %%
pd_telecomm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   gender            7267 non-null   object
#  2   SeniorCitizen     7267 non-null   int64
#  3   Partner           7267 non-null   category
#  4   Dependents        7267 non-null   category
#  5   tenure            7267 non-null   int64
#  6   PhoneService      7267 non-null   category
#  7   MultipleLines     7267 non-null   category
#  8   InternetService   7267 non-null   object
#  9   OnlineSecurity    7267 non-null   category
#  10  OnlineBackup      7267 non-null   category
#  11  DeviceProtection  7267 non-null   category
#  12  TechSupport       7267 non-null   category
#  13  StreamingTV       7267 non-null   category
#  14  StreamingMovies   7267 non-null   category
#  15  Contract          7267 non-null   object
# ...

# %%
pd_telecomm.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  0003-MKNFE    Male              0      No         No       9          Yes
# 2  0004-TLHLJ    Male              0      No         No       4          Yes
# 3  0011-IGKFF    Male              1     Yes         No      13          Yes
# 4  0013-EXCHZ  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1           Yes             DSL             No  ...               No
# 2            No     Fiber optic             No  ...              Yes
# 3            No     Fiber optic             No  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
pd_telecomm['Charges.Daily'] = pd_telecomm['Charges.Monthly'] / 30

# %%
pd_telecomm.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  0003-MKNFE    Male              0      No         No       9          Yes
# 2  0004-TLHLJ    Male              0      No         No       4          Yes
# 3  0011-IGKFF    Male              1     Yes         No      13          Yes
# 4  0013-EXCHZ  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... TechSupport StreamingTV  \
# 0            No             DSL             No  ...         Yes         Yes
# 1           Yes             DSL             No  ...          No          No
# 2            No     Fiber optic             No  ...          No          No
# 3            No     Fiber optic             No  ...          No         Yes
# 4            No     Fiber optic             No  ...         Yes         Yes
#
# ...

# %%
pd_telecomm['Partner'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['Dependents'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['PhoneService'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['MultipleLines'].unique()
# Out:
# ['No', 'Yes', 'No phone service']
# Categories (3, object): ['No', 'No phone service', 'Yes']

# %%
pd_telecomm['MultipleLines'].unique()
# Out:
# ['No', 'Yes', 'No phone service']
# Categories (3, object): ['No', 'No phone service', 'Yes']

# %%
pd_telecomm['MultipleLines'] = pd_telecomm['MultipleLines'].astype(str).replace('No phone service', 'No')

# %%
pd_telecomm['MultipleLines'] = pd_telecomm['MultipleLines'].astype('category')

# %%
pd_telecomm['MultipleLines'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['OnlineSecurity'].unique()
# Out:
# ['No', 'Yes', 'No internet service']
# Categories (3, object): ['No', 'No internet service', 'Yes']

# %%
pd_telecomm['OnlineSecurity'] = pd_telecomm['OnlineSecurity'].astype(str).replace('No internet service', 'No')

# %%
pd_telecomm['OnlineSecurity'] = pd_telecomm['OnlineSecurity'].astype('category')

# %%
pd_telecomm['OnlineSecurity'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['OnlineBackup'].unique()
# Out:
# ['Yes', 'No', 'No internet service']
# Categories (3, object): ['No', 'No internet service', 'Yes']

# %%
pd_telecomm['OnlineBackup'] = pd_telecomm['OnlineBackup'].astype(str).replace('No internet service', 'No')

# %%
pd_telecomm['OnlineBackup'] = pd_telecomm['OnlineBackup'].astype('category')

# %%
pd_telecomm['OnlineBackup'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['DeviceProtection'].unique()
# Out:
# ['No', 'Yes', 'No internet service']
# Categories (3, object): ['No', 'No internet service', 'Yes']

# %%
pd_telecomm['DeviceProtection'] = pd_telecomm['DeviceProtection'].astype(str).replace('No internet service', 'No')

# %%
pd_telecomm['DeviceProtection'] = pd_telecomm['DeviceProtection'].astype('category')

# %%
pd_telecomm['DeviceProtection'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['TechSupport'].unique()
# Out:
# ['Yes', 'No', 'No internet service']
# Categories (3, object): ['No', 'No internet service', 'Yes']

# %%
pd_telecomm['TechSupport'] = pd_telecomm['TechSupport'].astype(str).replace('No internet service', 'No')

# %%
pd_telecomm['TechSupport'] = pd_telecomm['TechSupport'].astype('category')

# %%
pd_telecomm['TechSupport'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['StreamingTV'].unique()
# Out:
# ['Yes', 'No', 'No internet service']
# Categories (3, object): ['No', 'No internet service', 'Yes']

# %%
pd_telecomm[['StreamingTV','StreamingMovies']] = pd_telecomm[['StreamingTV','StreamingMovies']].astype(str).replace('No internet service', 'No')

# %%
pd_telecomm['StreamingTV'] = pd_telecomm['StreamingTV'].astype('category')

# %%
pd_telecomm['StreamingMovies'] = pd_telecomm['StreamingMovies'].astype('category')

# %%
pd_telecomm['StreamingTV'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['StreamingMovies'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['PaperlessBilling'].unique()
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['Churn'].unique()
# Out:
# ['No', 'Yes', NaN]
# Categories (2, object): ['No', 'Yes']

# %%
pd_telecomm['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
pd_telecomm['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
pd_telecomm['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
pd_telecomm['PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
pd_telecomm.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  0003-MKNFE    Male              0      No         No       9          Yes
# 2  0004-TLHLJ    Male              0      No         No       4          Yes
# 3  0011-IGKFF    Male              1     Yes         No      13          Yes
# 4  0013-EXCHZ  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... TechSupport StreamingTV  \
# 0            No             DSL             No  ...         Yes         Yes
# 1           Yes             DSL             No  ...          No          No
# 2            No     Fiber optic             No  ...          No          No
# 3            No     Fiber optic             No  ...          No         Yes
# 4            No     Fiber optic             No  ...         Yes         Yes
#
# ...

# %%
pd_telecomm.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Charges.Total  \
# count    7267.000000  7267.000000      7267.000000    7256.000000
# mean        0.162653    32.346498        64.720098    2280.634213
# std         0.369074    24.571773        30.129572    2268.632997
# min         0.000000     0.000000        18.250000      18.800000
# 25%         0.000000     9.000000        35.425000     400.225000
# 50%         0.000000    29.000000        70.300000    1391.000000
# 75%         0.000000    55.000000        89.875000    3785.300000
# max         1.000000    72.000000       118.750000    8684.800000
#
#        Charges.Daily
# count    7267.000000
# mean        2.157337
# std         1.004319
# min         0.608333
# 25%         1.180833
# 50%         2.343333
# 75%         2.995833
# max         3.958333

# %% [markdown]
# #📊 Carga y análisis

# %%
pd_telecomm['churn_yes'] = pd_telecomm['Churn'] == 'Yes'

# %%
pd_telecomm['churn_no'] = pd_telecomm['Churn'] == 'No'

# %%
churn_yes = pd_telecomm['churn_yes'].sum()

# %%
churn_no = pd_telecomm['churn_no'].sum()

# %%
import matplotlib.pyplot as plt

# %%
churn_counts = pd_telecomm['Churn'].value_counts()
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%')
plt.title('Churn Distribution')
plt.show()

# %%
churn_counts
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
pd_telecomm.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0002-ORFBO  Female              0     Yes        Yes       9          Yes
# 1  0003-MKNFE    Male              0      No         No       9          Yes
# 2  0004-TLHLJ    Male              0      No         No       4          Yes
# 3  0011-IGKFF    Male              1     Yes         No      13          Yes
# 4  0013-EXCHZ  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... StreamingMovies  \
# 0            No             DSL             No  ...              No
# 1           Yes             DSL             No  ...             Yes
# 2            No     Fiber optic             No  ...              No
# 3            No     Fiber optic             No  ...             Yes
# 4            No     Fiber optic             No  ...              No
#
#          Contract PaperlessBilling     PaymentMethod Charges.Monthly  \
# ...

# %%
churn_genre = pd_telecomm[pd_telecomm['Churn'] == 'Yes'].groupby(['gender'])['Churn'].count()

# %%
churn_genre
# Out:
# gender
# Female    939
# Male      930
# Name: Churn, dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(churn_genre.index, churn_genre.values,
        color=['#1f77b4', '#ff7f0e'])

# Agregar los valores numéricos encima de cada barra
for index, value in enumerate(churn_genre.values):
    plt.text(index, value + 0.5,  # Posición del texto (x, y)
             str(value),          # Texto a mostrar (convertimos el valor a string)
             ha='center',         # Alineación horizontal centrada
             va='bottom')         # Alineación vertical en la parte inferior

# Personalización adicional
plt.xlabel('Gender')
plt.ylabel('Churn Count')
plt.title('Churn Count by Gender')
plt.ylim(0, max(churn_genre.values) * 1.1)  # Ajustar el límite superior del eje Y

plt.show()

# %%
pd_telecomm['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
churn_contract = pd_telecomm[pd_telecomm['Churn'] == 'Yes'].groupby(['Contract'])['Churn'].count()

# %%
plt.bar(churn_contract.index, churn_contract.values,
        color=['#F5F5DC', '#00FFFF', '#FF0000'])

# Agregar los valores numéricos encima de cada barra
for index, value in enumerate(churn_contract.values):
    plt.text(index, value + 0.5,  # Posición del texto (x, y)
             str(value),          # Texto a mostrar (convertimos el valor a string)
             ha='center',         # Alineación horizontal centrada
             va='bottom')         # Alineación vertical en la parte inferior

# Personalización adicional
plt.xlabel('Type of contract')
plt.ylabel('Churn Count')
plt.title('Churn Count by Type of Contract')
plt.ylim(0, max(churn_contract.values) * 1.1)  # Ajustar el límite superior del eje Y
# Out:
# (0.0, 1820.5000000000002)

# %%
churn_contract
# Out:
# Contract
# Month-to-month    1655
# One year           166
# Two year            48
# Name: Churn, dtype: int64

# %%
churn_payment_method = pd_telecomm[pd_telecomm['Churn'] == 'Yes'].groupby(['PaymentMethod'])['Churn'].count()

# %%
plt.bar(churn_payment_method.index, churn_payment_method.values,
        color=['#8A2BE2', '#7FFF00', '#BFBF00', '#000000'])

# Agregar los valores numéricos encima de cada barra
for index, value in enumerate(churn_payment_method.values):
    plt.text(index, value + 0.5,  # Posición del texto (x, y)
             str(value),          # Texto a mostrar (convertimos el valor a string)
             ha='center',         # Alineación horizontal centrada
             va='bottom')         # Alineación vertical en la parte inferior

# Personalización adicional
plt.xlabel('Payment Method')
plt.ylabel('Churn Count')
plt.xticks(rotation=45)
plt.title('Churn Count by Payment Method')
plt.ylim(0, max(churn_payment_method.values) * 1.1)  # Ajustar el límite superior del eje Y
# Out:
# (0.0, 1178.1000000000001)

# %%
churn_payment_method
# Out:
# PaymentMethod
# Bank transfer (automatic)     258
# Credit card (automatic)       232
# Electronic check             1071
# Mailed check                  308
# Name: Churn, dtype: int64

# %%
churn_yes
# Out:
# np.int64(1869)

# %%
churn_clean = pd_telecomm['Churn'].dropna()

# %%
churn_clean
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7043, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
churn_yes
# Out:
# np.int64(1869)

# %%
churn_no
# Out:
# np.int64(5174)

# %%
# Drop rows where 'Churn' is null before grouping
churn_charge_total = pd_telecomm.dropna(subset=['Churn']).groupby('Churn')['Charges.Total'].count()
# Out:
# /tmp/ipython-input-110-2283803328.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_charge_total = pd_telecomm.dropna(subset=['Churn']).groupby('Churn')['Charges.Total'].count()

# %%
churn_charge_total
# Out:
# Churn
# No     5163
# Yes    1869
# Name: Charges.Total, dtype: int64

# %%
pd_telecomm['Charges.Total'].count()
# Out:
# np.int64(7256)

# %%
pd_telecomm['Charges.Total']
# Out:
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40
#          ...
# 7262     742.90
# 7263    1873.70
# 7264      92.75
# 7265    4627.65
# 7266    3707.60
# Name: Charges.Total, Length: 7267, dtype: float64

# %%
charges_total = pd_telecomm['Charges.Total'].dropna()

# %%
charges_total
# Out:
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40
#          ...
# 7262     742.90
# 7263    1873.70
# 7264      92.75
# 7265    4627.65
# 7266    3707.60
# Name: Charges.Total, Length: 7256, dtype: float64

# %%
churn_charge_total = pd_telecomm.dropna(subset=['Churn', 'Charges.Total']).groupby('Churn', observed=True)['Charges.Total'].sum()

# %%
churn_charge_total
# Out:
# Churn
# No     13193241.8
# Yes     2862926.9
# Name: Charges.Total, dtype: float64

# %%
charges_total.sum()
# Out:
# np.float64(16548281.85)

# %%
pd_telecomm_dropna_churn = pd_telecomm.dropna(subset=['Churn'])

# %%
pd_telecomm_proof = pd_telecomm_dropna_churn['Charges.Total'].sum()

# %%
pd_telecomm_proof
# Out:
# np.float64(16056168.7)

# %%
plt.bar(churn_charge_total.index, churn_charge_total.values,
        color=['#00BFFF', '#FFFAF0'])

# Agregar los valores numéricos encima de cada barra
for index, value in enumerate(churn_charge_total.values):
    plt.text(index, value + 0.5,  # Posición del texto (x, y)
             str(value),          # Texto a mostrar (convertimos el valor a string)
             ha='center',         # Alineación horizontal centrada
             va='bottom')         # Alineación vertical en la parte inferior

# Personalización adicional
plt.xlabel('Churn response')
plt.ylabel('Total spent per year')
plt.title('Total spent per year vs Churn Response')
plt.ylim(0, max(churn_charge_total.values) * 1.1)  # Ajustar el límite superior del eje Y
# Out:
# (0.0, 14512565.980000002)

# %%
tenure = pd_telecomm['tenure'].dropna()

# %%
tenure
# Out:
# 0        9
# 1        9
# 2        4
# 3       13
# 4        3
#         ..
# 7262    13
# 7263    22
# 7264     2
# 7265    67
# 7266    63
# Name: tenure, Length: 7267, dtype: int64

# %%
tenure_churn = pd_telecomm.dropna(subset=['Churn', 'tenure']).groupby('Churn', observed=True)['tenure'].sum()

# %%
tenure_churn
# Out:
# Churn
# No     194387
# Yes     33603
# Name: tenure, dtype: int64

# %%
tenure
# Out:
# 0        9
# 1        9
# 2        4
# 3       13
# 4        3
#         ..
# 7262    13
# 7263    22
# 7264     2
# 7265    67
# 7266    63
# Name: tenure, Length: 7267, dtype: int64

# %%
tenure_describe = tenure_churn = pd_telecomm.dropna(subset=['Churn', 'tenure']).groupby('Churn', observed=True)['tenure']

# %%
tenure_describe.describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
pd_telecomm['tenure'].unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=pd_telecomm, x='Churn', y='tenure')
plt.title("Distribución del tiempo de contrato por estado de cancelación")
plt.xlabel("¿Canceló?")
plt.ylabel("Meses de contrato")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Suponiendo que ya tienes tu DataFrame llamado pd_telecomm

# Crear el boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(data=pd_telecomm, x='Churn', y='tenure')

# Calcular estadísticos por grupo
stats = pd_telecomm.groupby('Churn')['tenure'].describe()

# Añadir anotaciones (mediana, Q1, Q3)
for i, churn_status in enumerate(stats.index):
    q1 = stats.loc[churn_status, '25%']
    median = stats.loc[churn_status, '50%']
    q3 = stats.loc[churn_status, '75%']

    # Mostrar texto sobre la caja
    plt.text(i - 0.2, q1, f'Q1: {q1:.1f}', color='blue', fontsize=9)
    plt.text(i - 0.2, median, f'Med: {median:.1f}', color='red', fontsize=9)
    plt.text(i - 0.2, q3, f'Q3: {q3:.1f}', color='brown', fontsize=9)

# Personalizar el gráfico
plt.title("Distribución de tiempo de contrato por cancelación")
plt.xlabel("¿Canceló?")
plt.ylabel("Meses de contrato")
plt.tight_layout()
plt.savefig("grafico.png")
plt.show()
# Out:
# /tmp/ipython-input-132-3646928305.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stats = pd_telecomm.groupby('Churn')['tenure'].describe()

# %%
plt.savefig('mi_grafico.png', dpi=300, bbox_inches='tight')

# %%
stats
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %% [markdown]
# #📄Informe final

# %% [markdown]
# # Informe Final: Análisis de Evasión de Clientes (Churn) - TelecomX LATAM
#
# ## 🔹 Introducción
#
# En este análisis se estudió el fenómeno de **evasión de clientes** (*Churn*) en una empresa de telecomunicaciones de LATAM. El objetivo principal fue entender los factores que influyen en la decisión de los clientes de cancelar sus contratos, utilizando técnicas de análisis exploratorio de datos y visualización.
#
# Identificar estos patrones puede ayudar a la empresa a diseñar estrategias más efectivas de **retención**, enfocándose en los perfiles de clientes más propensos a cancelar.
#
# ---
#
# ## 🔹 Limpieza y Tratamiento de Datos
#
# Los pasos realizados en el tratamiento de datos incluyeron:
#
# - **Importación del dataset** original.
# - Revisión inicial de los datos, incluyendo tipos de variables y valores nulos.
# - Conversión de datos categóricos y numéricos al formato adecuado.
# - Identificación y manejo de valores faltantes o inconsistentes.
# - Transformación de columnas como `TotalCharges` a tipo numérico.
# - Creación de nuevas columnas si fueron necesarias (por ejemplo, columnas booleanas o codificadas).
#
# Este proceso permitió garantizar la **consistencia y calidad** de los datos para un análisis confiable.
#
# ---
#
# ## 🔹 Análisis Exploratorio de Datos (EDA)
#
# Se realizaron diversos análisis y visualizaciones para entender mejor la distribución y comportamiento de los clientes:
#
# - **Distribución de cancelaciones (`Churn`) por género, tipo de contrato, servicios adicionales y formas de pago.**
# - **Gráficos de barras** para identificar categorías con mayor proporción de cancelación.
# - **Boxplots** para comparar la duración del contrato entre clientes que cancelaron y los que no:
#     - Se observó que la mediana del tiempo de contrato en clientes que cancelaron es significativamente menor.
#     - Clientes con contratos más cortos tienen una tasa de cancelación más alta.
# - Se detectaron **asimetrías en los datos**: por ejemplo, la duración del contrato está sesgada hacia valores bajos en los clientes que cancelaron.
# - **Correlación entre variables numéricas** y el churn.
#
# ---
#
# ## 🔹 Conclusiones e Insights
#
# A partir del análisis se identificaron los siguientes hallazgos clave:
#
# - Los clientes que **cancelan tienden a tener contratos de corto plazo**, y frecuentemente no usan servicios adicionales como internet o líneas múltiples.
# - Hay una mayor tasa de cancelación entre quienes pagan mediante **métodos electrónicos o mes a mes**, lo que puede indicar menor compromiso.
# - Clientes que tienen contratos anuales o de dos años presentan **menor tasa de churn**.
# - La **duración del contrato** es una de las variables más influyentes en la cancelación.
# - Se identificaron **segmentos específicos de clientes** con mayor propensión a cancelar, útiles para estrategias de retención.
#
# ---
#
# ## 🔹 Recomendaciones
#
# Con base en los hallazgos anteriores, se sugieren las siguientes acciones estratégicas:
#
# 1. 🎯 **Focalizar campañas de retención** en los primeros meses de contrato, especialmente en los clientes con planes mensuales.
# 2. 💡 **Ofrecer incentivos o descuentos** a clientes nuevos para que opten por contratos más largos desde el inicio.
# 3. 📞 **Implementar seguimiento proactivo** a clientes con pocos servicios contratados (ej. sin internet o líneas adicionales).
# 4. 🧠 **Usar modelos predictivos** entrenados con estas variables clave para anticipar posibles cancelaciones.
# 5. 💳 Analizar más a fondo las **preferencias de métodos de pago** y su relación con la lealtad del cliente.
#
# ---
#
# > 📌 Este análisis proporciona una base sólida para el desarrollo de políticas de fidelización que reduzcan la tasa de evasión de clientes en TelecomX LATAM.
